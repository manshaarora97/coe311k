# %%
i = 2147483647
i = i + 1
print(i)
# Out:
# 2147483648

# %%
print(i + 1)
print(i)
# Out:
# 2147483649
# 2147483648

# %%
floating point arithmetic: finite number of bits to 
Round off error: difference between actual number and rounded number
Machine epsilon: t is the amount of bits to represent fractional part (mantissa)
round off error: when a machine identifies an error when perfroming artimetic operations
loss of prevision: when subtracting two, data can be lost

# %%
print(i + .00001)
# Out:
# 2147483648.00001

# %%
i+2**2
# Out:
# 2147483652
