# %%
#ctime((secs)) right before u call guass seidel function print/save current time - start, after calling print/save current time - start

# %%
import time
import datetime

# %%
import numpy as np
def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        
# Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
    
        x = x_new
    return x, max_iterations

# %%
# Example usage

A = np.array([[10, -1, 2, 0, 0],
[-1, 11, -1, 3, 0],
[-2, -1, 10, -1, 0],
[0, 3, -1, 8, -2], [0, 0, 0, 2, -9]])
b = np.array([14, 30, 26, 25, 37])
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100
solution, iterations = jacobi(A, b, x0, tol, max_iterations)
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
# Out:
# Solution: [ 1  2  3  2 -3]
# Iterations: 3

# %%
import numpy as np
import timeit

def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    
    for k in range(max_iterations):
        x_new = x.copy()
        
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
            
# Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
        #return x_new, k, time_elapsed
            x = x_new

    return x, max_iterations

#t1 = timeit.default_timer()
#gauss_seidel(A, b, x0, tol, max_iterations)
#t2 = timeit.default_timer()
#time_elapsed = t1-t2

# %%
# Example usage

from time import gmtime, strftime
import timeit

A = np.array([[10, -1, 2, 0, 0],
[-1, 11, -1, 3, 0],
[-2, -1, 10, -1, 0],
[0, 3, -1, 8, -2], [0, 0, 0, 2, -9]])
b = np.array([14, 30, 26, 25, 37])
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100

#t1 = timeit.default_timer()
start_time = time.time()

solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)

end_time = time.time()
time_elapsed = end_time - start_time
#t2 = timeit.default_timer()
#time_elapsed = t2-t1

print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print(f"Time Elapsed: {time_elapsed}")
# Out:
# Solution: [0 0 0 0 0]
# Iterations: 100
# Time Elapsed: 0.005141735076904297

# %%
Part B

# %%
import numpy as np
def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        
# Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
    
        x = x_new
    return x, max_iterations

# %%
# Example usage

A = np.array([[1, 2, 3, 0, 0],
[2, 1, 2, 3, 0],
[3, 2, 1, 2, 3],
[0, 3, 2, 1, 2], [0, 0, 3, 2, 1]])
b = np.array([12, 22, 33, 26, 22])
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100
solution, iterations = jacobi(A, b, x0, tol, max_iterations)
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
# Out:
# Solution: [ 5803071047074590720  4220309694348404736  3684956515524952064
#  -6847736749885714432  2113722232336875520]
# Iterations: 100
# /tmp/ipykernel_4445/2079336407.py:8: RuntimeWarning: overflow encountered in scalar add
#   s = sum(A[i][j] * x[j] for j in range(n) if j != i)
# /tmp/ipykernel_4445/2079336407.py:8: RuntimeWarning: overflow encountered in scalar multiply
#   s = sum(A[i][j] * x[j] for j in range(n) if j != i)
