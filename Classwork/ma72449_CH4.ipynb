# %%
import math
import numpy as np 

summation = 0

for i in range(0,5000):
    summation = summation + ((-1**i)/((2*i)+1))
    summation_pi = 4*summation
    estimate = abs(summation_pi - np.pi)
    if(i % 100 == 0):
        print(estimate)
# Out:
# 7.141592653589793
# 16.29886190830876
# 17.675224584397068
# 18.48283415491242
# 19.056536078484108
# 19.50182523980609
# 19.865802805414713
# 20.173628649284897
# 20.44033472965273
# 20.6756233235017
# 20.886122347429968
# 21.07656104782344
# 21.250432407566624
# 21.410389711891526
# 21.55849584076299
# 21.69638640588727
# 21.825380164137513
# 21.94655591922554
# 22.060807421676163
# 22.168883413669228
# 22.27141739561262
# 22.3689501262011
# 22.46194688588753
# 22.550810901442652
# 22.635893912530655
# 22.71750458071052
# 22.795915248847866
# 22.871367424640574
# 22.944076266774502
# 23.01423428377743
# 23.082014405766433
# 23.14757255249943
# 23.21104979370527
# 23.272574176986623
# 23.33226228285151
# 23.39022055434076
# 23.446546439356815
# 23.501329376488783
# 23.55465164937907
# 23.60658913012195
# 23.65721192855278
# 23.706584961371657
# 23.75476845269322
# 23.801818375704908
# 23.847786843557216
# 23.892722456331853
# 23.93667060988006
# 23.979673771451683
# ...
