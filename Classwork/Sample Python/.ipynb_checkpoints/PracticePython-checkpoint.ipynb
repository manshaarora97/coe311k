# %% [markdown]
# Hello Python! This is my very first notebook

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Any String!")
# Out:
# Any String!

# %%
print(True)
# Out:
# True

# %%
2.3+5.5
# Out:
# 7.8

# %%
name = "Mansha"
NAME = "Arora"
print(name)
print(NAME)
# Out:
# Mansha
# Arora

# %%
type(name)
type(NAME)
# Out:
# str

# %%
def montecralo_pi(number_of_shots)
    import random 
    counter = 0;
    x = random.uniform(-1,1)
    y = random.uniform(-1,1)
    for i in range(0, number_of_shots)
        if(x**2 + y**2 < 1)
        number_of_hits = number_of_hits + 1;
