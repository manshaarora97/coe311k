# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np
def jacobi(A, b, x0, tol, max_iterations):
    tol = 1e-6
    max_iterations = 100
    errors = []
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        
        # Check for convergence
        errors.append(np.linalg.norm(x_new - x, ord=np.inf))
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k, errors 
    
        x = x_new
    return x, max_iterations, errors

# %%
def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = x.copy()
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
            # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations, errors

# %%
import numpy as np
A = np.array([
[0.582745, 0.48, 0.10	, 0.  	, 0.  	], 
 [0.48	, 1.044129, 0.46	, 0.10	, 0.  	],
 [0.10	, 0.46	, 1.10431 , 0.44	, 0.10	],
 [0.  	, 0.10	, 0.44	, 0.963889, 0.42	],
 [0.  	, 0.  	, 0.10	, 0.42	, 0.522565]], dtype=float)
b = np.array([1.162745, 2.084129, 2.20431 , 1.923889, 1.042565], dtype=float)
x0 = np.zeros_like(b)

# %%
solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)
print(f"g-s Solution: {solution}")
print(f"Iterations: {iterations}")

solution, iterations, errors = jacobi(A, b, x0, tol, max_iterations)
print(f"jacobi Solution: {solution}")
print(f"Iterations: {iterations}")

A = np.array([[1, 	1], [1, 1.0001]])
b = np.array([1, 1])
x0 = np.zeros_like(b)

solution, iterations, errors  = gauss_seidel(A, b, x0, tol, max_iterations)
print(f"g-s Solution: {solution}")
print(f"Iterations: {iterations}")

solution, iterations, errors  = jacobi(A, b, x0, tol, max_iterations)
print(f"jacobi Solution: {solution}")
print(f"Iterations: {iterations}")

A = np.array([[1, 	1], [1, 1.0001]])
b = np.array([1, 1.0001])
x0 = np.zeros_like(b)
tol = 1*(10**-6)
max_iterations = 100

solution, iterations, errors = jacobi(A, b, x0, tol, max_iterations)
print(f"jacobi Solution: {solution}")
print(f"Iterations: {iterations}")

solution, iterations, errors = gauss_seidel(A, b, x0, tol, max_iterations)
print(f"g-s Solution: {solution}")
print(f"Iterations: {iterations}")
# Out:
# g-s Solution: [1 0]
# Iterations: 1
# jacobi Solution: [1 0]
# Iterations: 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 13
#      10 b = np.array([1, 1])
#      11 x0 = np.zeros_like(b)
# ---> 13 solution, iterations, errors  = gauss_seidel(A, b, x0, tol, max_iterations)
#      14 print(f"g-s Solution: {solution}")
#      15 print(f"Iterations: {iterations}")
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
def diagonal(A):
    for i in range(0,len(A)):
        sum = 0
        for j in range(0,len(A)):
            sum += A[i][j]
        sum = sum - A[i][i]
        if(A[i][i]<sum):
            return False
        
        
    return True

# %%
A = np.array([
	[0.0, 0.48	, 0.10	, 0.  	, 0.  	], 
 [0.48	, 1.044129, 0.46	, 0.10	, 0.  	],
 [0.10	, 0.46	, 1.10431 , 0.44	, 0.10	],
 [0.  	, 0.10	, 0.44	, 0.963889, 0.42	],
 [0.  	, 0.  	, 0.10	, 0.42	, 0.522565]], dtype=float)
diagdomtest = diagdom(A)
print(diagdomtest)

A = np.array([
	[0.582745, 0.48	, 0.10	, 0.  	, 0.  	], 
 [0.48	, 1.044129, 0.46	, 0.10	, 0.  	],
 [0.10	, 0.46	, 1.10431 , 0.44	, 0.10	],
 [0.  	, 0.10	, 0.44	, 0.963889, 0.42	],
 [0.  	, 0.  	, 0.10	, 0.42	, 0.522565]], dtype=float)
diagdomtest = diagdom(A)
print(diagdomtest)
# Out:
# True
# False
