# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline

# %%
# Define known data points
x = np.array([0, 1, 2, 3, 4, 5])

y = np.array([0, 1, 0, 1, 0, 1])


# Create a cubic spline interpolation of the data
cs = CubicSpline(x, y, bc_type='natural')

# Generate new x values for a smooth plot
x_int = np.linspace(0, 5, 100)
y_int = cs(x_int)

# %%
# Plot original data and cubic spline interpolation
plt.plot(x, y, 'bo' ,label="Data points") #plotted on same graph 
plt.plot(x_interp, y_interp, '-', label="Cubic Spline Interpolation")
plt.title("Cubic Spline Interpolation")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()

# %%
# Create a polyfit
coefficients = np.polyfit(x, y, 3)
polynomial = np.poly1d(coefficients)
y_pred = polynomial(x)

plt.xlabel('x')
plt.ylabel('y')
plt.title("Polyfit vs. Cubic Spline")
plt.scatter(x, y, color='blue', label='Data points') # Original data points
plt.plot(x, y_pred, color='red', label=f'Polynomial fit of degree')
plt.plot(x_int, y_int, '-', label="Cubic Spline Interpolation")
plt.legend()
plt.show()
