# %%
num = 2025
num_Arr = num
counter = 0
while num_Arr > 0: 
    num_Arr = num_Arr // 2 #asked gemini why my division wasn't working- told me '//' is int division
    counter = counter + 1
    
binary_arr = []  # was doing [None] * counter asked what the issue was with that told me to use '[]' instead 

for x in range(counter):
    if (num % 2 == 1) :
        binary_arr.insert(0, 1)
    else: 
        binary_arr.insert(0, 0)
    num = num // 2
    
for x in binary_arr :
    print(x, end="") #asked how to all print in same row
# Out:
# 11111101001
