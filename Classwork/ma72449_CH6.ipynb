# %%
#ctime((secs)) right before u call guass seidel function print/save current time - start, after calling print/save current time - start

# %%
import time
import datetime
import numpy as np

# %%
import numpy as np
def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        
# Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
    
        x = x_new
    return x, max_iterations

# %%
# Example usage

A = np.array([[10, -1, 2, 0, 0],
[-1, 11, -1, 3, 0],
[-2, -1, 10, -1, 0],
[0, 3, -1, 8, -2], [0, 0, 0, 2, -9]])
b = np.array([14, 30, 26, 25, 37])
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100
solution, iterations = jacobi(A, b, x0, tol, max_iterations)
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
# Out:
# Solution: [ 1  2  3  2 -3]
# Iterations: 3

# %%
import numpy as np
import timeit
import time

def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    
    for k in range(max_iterations):
        x_new = x.copy()
        
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
            
# Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
        #return x_new, k, time_elapsed
            x = x_new

    return x, max_iterations

# %%
# Out:
# UsageError: %%time is a cell magic, but the cell body is empty. Did you mean the line magic %time (single %)?

# %%
# Example usage

from time import gmtime, strftime
import timeit

A = np.array([[10, -1, 2, 0, 0],
[-1, 11, -1, 3, 0],
[-2, -1, 10, -1, 0],
[0, 3, -1, 8, -2], [0, 0, 0, 2, -9]])
b = np.array([14, 30, 26, 25, 37])
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100

# %%
# %%time 

solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)

print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print(f"Time Elapsed: {time_elapsed}")
# Out:
# Solution: [0 0 0 0 0]
# Iterations: 100
# Time Elapsed: 0.0054895877838134766
# CPU times: user 6.84 ms, sys: 0 ns, total: 6.84 ms
# Wall time: 6.3 ms

# %%
#Part B

# %%
import numpy as np
def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        
# Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
    
        x = x_new
    return x, max_iterations

# %%
# Example usage

A = np.array([[1, 2, 3, 0, 0],
[2, 1, 2, 3, 0],
[3, 2, 1, 2, 3],
[0, 3, 2, 1, 2], [0, 0, 3, 2, 1]])
b = np.array([12, 22, 33, 26, 22])
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100
solution, iterations = jacobi(A, b, x0, tol, max_iterations)
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
# Out:
# Solution: [ 5803071047074590720  4220309694348404736  3684956515524952064
#  -6847736749885714432  2113722232336875520]
# Iterations: 100
# /tmp/ipykernel_5169/230201056.py:8: RuntimeWarning: overflow encountered in scalar add
#   s = sum(A[i][j] * x[j] for j in range(n) if j != i)
# /tmp/ipykernel_5169/230201056.py:8: RuntimeWarning: overflow encountered in scalar multiply
#   s = sum(A[i][j] * x[j] for j in range(n) if j != i)

# %%
import numpy as np
import timeit
import time

def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    
    for k in range(max_iterations):
        x_new = x.copy()
        
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
            
# Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
        #return x_new, k, time_elapsed
            x = x_new

    return x, max_iterations

# %%
# Example usage

A = np.array([[1, 2, 3, 0, 0],
[2, 1, 2, 3, 0],
[3, 2, 1, 2, 3],
[0, 3, 2, 1, 2], [0, 0, 3, 2, 1]])
b = np.array([14, 22, 33, 26, 22])
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100
solution, iterations = jacobi(A, b, x0, tol, max_iterations)
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
# Out:
# Solution: [-5976176488926883840 -4324294422220818432   125198747742650400
#  -4324294422220818432 -5976176488926883840]
# Iterations: 100
# /tmp/ipykernel_5169/230201056.py:8: RuntimeWarning: overflow encountered in scalar add
#   s = sum(A[i][j] * x[j] for j in range(n) if j != i)
# /tmp/ipykernel_5169/230201056.py:8: RuntimeWarning: overflow encountered in scalar multiply
#   s = sum(A[i][j] * x[j] for j in range(n) if j != i)

# %%
# %%time 

solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)

print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print(f"Time Elapsed: {time_elapsed}")
# Out:
# Solution: [0 0 0 0 0]
# Iterations: 100
# Time Elapsed: 0.0054895877838134766
# CPU times: user 3.22 ms, sys: 0 ns, total: 3.22 ms
# Wall time: 3.24 ms

# %%
#In part B, the matrix does not converge
