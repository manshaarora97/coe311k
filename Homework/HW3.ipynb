# %%
import numpy as np
import matplotlib.pyplot as plt
from

# %%
n = int(input('Enter the amount of terms you want to use for your apporoximation: '))

aprx = 0
approximations = []

for i in range(n):
    numerator = ((-1)**i) * (x**(2*i + 1))
    denominator = math.factorial((2*i)+1))
    aprx = aprx + (numerator/denominator) 

approximations.append(aprx)

x = np.arange(0,10.1, 0.1)
exact = np.sin(x)
