# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def taylorAprx (n):

    range = np.arange(0,10.1, 0.1)

    for i in range:
        aprx = 0
    for z in range(n):
        numerator = ((-1)**z) * (i**(2*z + 1))
        denominator = math.factorial(2*z+1)
        aprx = aprx + (numerator/denominator) 
    


    exact = np.sin(x)
    error = np.abs(exact - aprx)
    return error

# %%
aprx_one = taylorAprx(1)
aprx_two = taylorAprx(2)
aprx_three = taylorAprx(3)
aprx_four = taylorAprx(4)

print(aprx_one)
print(aprx_two)
print(aprx_three)
print(aprx_four)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 aprx_one = taylorAprx(1)
#       2 aprx_two = taylorAprx(2)
#       3 aprx_three = taylorAprx(3)
#
# Cell In[26], line 7, in taylorAprx(n)
#       5 for i in range:
#       6     aprx = 0
# ----> 7 for z in range(n):
#       8     numerator = ((-1)**z) * (i**(2*z + 1))
#       9     denominator = math.factorial(2*z+1)
#
# TypeError: 'numpy.ndarray' object is not callable
